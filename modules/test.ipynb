# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
print("Hello ML")

pd.read_csv("../data/preprocessExample.csv")

X = np.array([[1], [2], [3], [4], [5]])
y = np.array([3,5,7,9,11])

model = LinearRegression()
model.fit(X,y)
print("Model is trainied")

new_data = np.array([[6]])

prediction = model.predict(new_data)

print(f"The models prediction is {prediction}")
# Out:
# Hello ML
# Model is trainied
# The models prediction is [13.]
