# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("../../data/Social_Network_Ads.csv")

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Age              400 non-null    int64
#  1   EstimatedSalary  400 non-null    int64
#  2   Purchased        400 non-null    int64
# dtypes: int64(3)
# memory usage: 9.5 KB

# %%
features = data.iloc[:, [0,1]].values
labels = data.iloc[:, [2]].values

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    features,
    labels,
    train_size=0.2,
    random_state=1
)

# %%
from sklearn.neighbors import KNeighborsClassifier

model = KNeighborsClassifier()
model.fit(X_train, y_train)
# Out:
# /opt/anaconda3/envs/ml/lib/python3.13/site-packages/sklearn/neighbors/_classification.py:239: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNeighborsClassifier()

# %%
print(f"Train Score: {model.score(X_train, y_train)}, Test Score: {model.score(X_test, y_test)}")
# Out:
# Train Score: 0.8625, Test Score: 0.7625

# %% [markdown]
# # Bagging with Shuffling Method

# %%
# Since I am dealing with an OVERFITTED MODEL, I shall use Bagging with an expectation of the model getting balanced

from sklearn.ensemble import BaggingClassifier
from sklearn.neighbors import KNeighborsClassifier


algo = KNeighborsClassifier()

ensembleModel = BaggingClassifier(n_estimators=42, estimator=algo)

ensembleModel.fit(X_train, y_train)
# Out:
# /opt/anaconda3/envs/ml/lib/python3.13/site-packages/sklearn/ensemble/_bagging.py:878: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# BaggingClassifier(estimator=KNeighborsClassifier(), n_estimators=42)

# %%
print(f"Train Score: {ensembleModel.score(X_train, y_train)}, Test Score: {ensembleModel.score(X_test, y_test)}")
# Out:
# Train Score: 0.8875, Test Score: 0.7875

# %% [markdown]
# # Bagging with Sampling Method
# ## 1. Sampling with Replacement

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.neighbors import KNeighborsClassifier

#Guideline by PN for Sample Size
sampleSize = int(round(np.sqrt(len(X_train))))

algo = KNeighborsClassifier()

ensembleModel1 = BaggingClassifier(n_estimators=42, 
                                   estimator=algo, max_samples=sampleSize, bootstrap=True) #Sample with Replacement

ensembleModel1.fit(X_train,y_train)
# Out:
# /opt/anaconda3/envs/ml/lib/python3.13/site-packages/sklearn/ensemble/_bagging.py:878: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# BaggingClassifier(estimator=KNeighborsClassifier(), max_samples=9,
#                   n_estimators=42)

# %%
print(f"Training Score is {ensembleModel1.score(X_train,y_train)} and Testing Score is {ensembleModel1.score(X_test,y_test)}")
# Out:
# Training Score is 0.625 and Testing Score is 0.646875

# %% [markdown]
# ## 2. Sampling without Replacement

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.neighbors import KNeighborsClassifier

#Guideline by PN for Sample Size
sampleSize = int(round(np.sqrt(len(X_train))))

algo = KNeighborsClassifier()

ensembleModel2 = BaggingClassifier(n_estimators=42, 
                                   estimator=algo, max_samples=sampleSize, bootstrap=False) #Sample with Replacement

ensembleModel2.fit(X_train,y_train)
# Out:
# /opt/anaconda3/envs/ml/lib/python3.13/site-packages/sklearn/ensemble/_bagging.py:878: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# BaggingClassifier(bootstrap=False, estimator=KNeighborsClassifier(),
#                   max_samples=9, n_estimators=42)

# %%
print(f"Training Score is {ensembleModel2.score(X_train,y_train)} and Testing Score is {ensembleModel2.score(X_test,y_test)}")
# Out:
# Training Score is 0.625 and Testing Score is 0.646875

# %% [markdown]
# # **Bagging with Shuffling Method - nLogisticRegression**

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.linear_model import LogisticRegression

algo = LogisticRegression()

ensembleModel = BaggingClassifier(n_estimators=42, estimator=algo)

ensembleModel.fit(X_train,y_train)
# Out:
# /opt/anaconda3/envs/ml/lib/python3.13/site-packages/sklearn/ensemble/_bagging.py:878: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# BaggingClassifier(estimator=LogisticRegression(), n_estimators=42)

# %%
print(f"Training Score is {ensembleModel.score(X_train,y_train)} and Testing Score is {ensembleModel.score(X_test,y_test)}")
# Out:
# Training Score is 0.9 and Testing Score is 0.828125

# %% [markdown]
# # Bagging with Sampling Method
# ## 1. Sampling with Replacement

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.linear_model import LogisticRegression

algo = LogisticRegression()

#Guideline by PN for Sample Size
sampleSize = int(round(np.sqrt(len(X_train))))


ensembleModel1 = BaggingClassifier(n_estimators=42, estimator=algo, max_samples=sampleSize, bootstrap=True) #Sample with Replacement

ensembleModel1.fit(X_train,y_train)
# Out:
# /opt/anaconda3/envs/ml/lib/python3.13/site-packages/sklearn/ensemble/_bagging.py:878: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# BaggingClassifier(estimator=LogisticRegression(), max_samples=9,
#                   n_estimators=42)

# %%
print(f"Training Score is {ensembleModel1.score(X_train,y_train)} and Testing Score is {ensembleModel1.score(X_test,y_test)}")
# Out:
# Training Score is 0.8625 and Testing Score is 0.828125

# %% [markdown]
# # 2. Sampling without Replacement

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.linear_model import LogisticRegression

algo = LogisticRegression()

#Guideline by PN for Sample Size
sampleSize = int(round(np.sqrt(len(X_train))))



ensembleModel2 = BaggingClassifier(n_estimators=5, estimator=algo, max_samples=sampleSize, bootstrap=False, random_state=10) #Sample without Replacement

ensembleModel2.fit(X_train,y_train)
# Out:
# /opt/anaconda3/envs/ml/lib/python3.13/site-packages/sklearn/ensemble/_bagging.py:878: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# BaggingClassifier(bootstrap=False, estimator=LogisticRegression(),
#                   max_samples=9, n_estimators=5, random_state=10)

# %%
print(f"Training Score is {ensembleModel2.score(X_train,y_train)} and Testing Score is {ensembleModel2.score(X_test,y_test)}")
# Out:
# Training Score is 0.8625 and Testing Score is 0.81875
